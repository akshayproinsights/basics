# %%
print('Akshay..')
import time
import threading
# Out:
# Akshay..

# %%
def test(sec):
    time.sleep(sec)
    print(sec,"Donee...")

# %%
test(5)
# Out:
# 5 Donee...

# %%
t1 = threading.Thread(target=test, args=(5,)).start()
t2 = threading.Thread(target=test, args=(2,)).start()
t3 = threading.Thread(target=test, args=(10,)).start()
# Out:
# 2 Donee...
# 5 Donee...
# 10 Donee...
